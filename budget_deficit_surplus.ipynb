# %% [markdown]
# # Imports

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Read Excel file and find worksheet names

# %%
bud_xls_file = pd.ExcelFile('Fed_Budget_Deficit_Surplus_OMB_ERM.xlsx')
bud_xls_file.sheet_names
# Out:
# ['Table']

# %% [markdown]
# # Dataframe formatting and cleaning (drop rows, rename columns)

# %%
df = bud_xls_file.parse('Table')
df
# Out:
#    Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024  \
# 0                        (dollar amounts in billions)
# 1                                         Fiscal Year
# 2                                                 NaN
# 3                                                1940
# 4                                                1941
# ..                                                ...
# 84                                      2020 estimate
# 85                                      2021 estimate
# 86                                      2022 estimate
# 87                                      2023 estimate
# 88                                      2024 estimate
#
#             Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 0                  NaN        NaN                     NaN
# 1   In Current Dollars        NaN                     NaN
# 2             Receipts    Outlays  Surplus or Deficit (-)
# 3                  6.5        9.5                    -2.9
# 4                  8.7       13.7                    -4.9
# ..                 ...        ...                     ...
# 84              3644.8     4745.6                 -1100.8
# 85              3876.9     4945.2                 -1068.3
# 86              4128.6     5177.5                 -1048.8
# 87              4421.5     5330.1                  -908.6
# 88              4752.5       5453                  -700.5
#
#                        Unnamed: 4 Unnamed: 5              Unnamed: 6  \
# 0                             NaN        NaN                     NaN
# 1   In Constant (FY 2012) Dollars        NaN                     NaN
# 2                        Receipts    Outlays  Surplus or Deficit (-)
# 3                           100.3        145                   -44.7
# 4                           120.3      188.6                   -68.2
# ..                            ...        ...                     ...
# 84                         3209.3     4178.5                  -969.3
# 85                         3339.8     4260.2                  -920.3
# 86                         3479.1     4362.9                  -883.8
# 87                         3644.8     4393.8                    -749
# 88                           3833     4397.9                  -564.9
#
#                       Unnamed: 7             Unnamed: 8 Unnamed: 9  \
# 0                            NaN                    NaN        NaN
# 1   Addendum: Composite Deflator  As Percentages of GDP        NaN
# 2                            NaN               Receipts    Outlays
# 3                         0.0653                    6.7        9.6
# 4                         0.0724                    7.5       11.7
# ..                           ...                    ...        ...
# 84                        1.1357                   16.3       21.2
# 85                        1.1608                   16.5         21
# 86                        1.1867                   16.7       20.9
# 87                        1.2131                     17       20.5
# 88                        1.2399                   17.4         20
#
#                Unnamed: 10
# 0                      NaN
# 1                      NaN
# 2   Surplus or Deficit (-)
# 3                       -3
# 4                     -4.3
# ..                     ...
# 84                    -4.9
# 85                    -4.5
# 86                    -4.2
# 87                    -3.5
# 88                    -2.6
#
# [89 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
df = df.rename(columns={'Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024':'Year',
                          'Unnamed: 1':'Current $ Receipts', 'Unnamed: 2':'Current $ Outlays', 'Unnamed: 3':'Current $ Surplus/Deficit', 'Unnamed: 4':'Constant $ Receipts', 'Unnamed: 5':'Constant $ Outlays',
                          'Unnamed: 6':'Constant $ Surplus/Deficit'})

# %%
df
# Out:
#                             Year  Current $ Receipts Current $ Outlays  \
# 0   (dollar amounts in billions)                 NaN               NaN
# 1                    Fiscal Year  In Current Dollars               NaN
# 2                            NaN            Receipts           Outlays
# 3                           1940                 6.5               9.5
# 4                           1941                 8.7              13.7
# ..                           ...                 ...               ...
# 84                 2020 estimate              3644.8            4745.6
# 85                 2021 estimate              3876.9            4945.2
# 86                 2022 estimate              4128.6            5177.5
# 87                 2023 estimate              4421.5            5330.1
# 88                 2024 estimate              4752.5              5453
#
#    Current $ Surplus/Deficit            Constant $ Receipts  \
# 0                        NaN                            NaN
# 1                        NaN  In Constant (FY 2012) Dollars
# 2     Surplus or Deficit (-)                       Receipts
# 3                       -2.9                          100.3
# 4                       -4.9                          120.3
# ..                       ...                            ...
# 84                   -1100.8                         3209.3
# 85                   -1068.3                         3339.8
# 86                   -1048.8                         3479.1
# 87                    -908.6                         3644.8
# 88                    -700.5                           3833
#
#    Constant $ Outlays Constant $ Surplus/Deficit  \
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2             Outlays     Surplus or Deficit (-)
# 3                 145                      -44.7
# 4               188.6                      -68.2
# ..                ...                        ...
# 84             4178.5                     -969.3
# 85             4260.2                     -920.3
# 86             4362.9                     -883.8
# 87             4393.8                       -749
# 88             4397.9                     -564.9
#
#                       Unnamed: 7             Unnamed: 8 Unnamed: 9  \
# 0                            NaN                    NaN        NaN
# 1   Addendum: Composite Deflator  As Percentages of GDP        NaN
# 2                            NaN               Receipts    Outlays
# 3                         0.0653                    6.7        9.6
# 4                         0.0724                    7.5       11.7
# ..                           ...                    ...        ...
# 84                        1.1357                   16.3       21.2
# 85                        1.1608                   16.5         21
# 86                        1.1867                   16.7       20.9
# 87                        1.2131                     17       20.5
# 88                        1.2399                   17.4         20
#
#                Unnamed: 10
# 0                      NaN
# 1                      NaN
# 2   Surplus or Deficit (-)
# 3                       -3
# 4                     -4.3
# ..                     ...
# 84                    -4.9
# 85                    -4.5
# 86                    -4.2
# 87                    -3.5
# 88                    -2.6
#
# [89 rows x 11 columns]

# %%
budget_df = df[['Year','Current $ Receipts','Current $ Outlays','Current $ Surplus/Deficit','Constant $ Receipts','Constant $ Outlays','Constant $ Surplus/Deficit']].copy()

# %%
budget_df
# Out:
#                             Year  Current $ Receipts Current $ Outlays  \
# 0   (dollar amounts in billions)                 NaN               NaN
# 1                    Fiscal Year  In Current Dollars               NaN
# 2                            NaN            Receipts           Outlays
# 3                           1940                 6.5               9.5
# 4                           1941                 8.7              13.7
# ..                           ...                 ...               ...
# 84                 2020 estimate              3644.8            4745.6
# 85                 2021 estimate              3876.9            4945.2
# 86                 2022 estimate              4128.6            5177.5
# 87                 2023 estimate              4421.5            5330.1
# 88                 2024 estimate              4752.5              5453
#
#    Current $ Surplus/Deficit            Constant $ Receipts  \
# 0                        NaN                            NaN
# 1                        NaN  In Constant (FY 2012) Dollars
# 2     Surplus or Deficit (-)                       Receipts
# 3                       -2.9                          100.3
# 4                       -4.9                          120.3
# ..                       ...                            ...
# 84                   -1100.8                         3209.3
# 85                   -1068.3                         3339.8
# 86                   -1048.8                         3479.1
# 87                    -908.6                         3644.8
# 88                    -700.5                           3833
#
#    Constant $ Outlays Constant $ Surplus/Deficit
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2             Outlays     Surplus or Deficit (-)
# 3                 145                      -44.7
# 4               188.6                      -68.2
# ..                ...                        ...
# 84             4178.5                     -969.3
# 85             4260.2                     -920.3
# 86             4362.9                     -883.8
# 87             4393.8                       -749
# 88             4397.9                     -564.9
#
# [89 rows x 7 columns]

# %%
budget_df = budget_df.drop(0)
budget_df = budget_df.drop(1)
budget_df = budget_df.drop(2)
budget_df = budget_df.drop(83)
budget_df = budget_df.drop(84)
budget_df = budget_df.drop(85)
budget_df = budget_df.drop(86)
budget_df = budget_df.drop(87)
budget_df = budget_df.drop(88)

# %%
budget_df.head(5)
# Out:
#    Year Current $ Receipts Current $ Outlays Current $ Surplus/Deficit  \
# 3  1940                6.5               9.5                      -2.9
# 4  1941                8.7              13.7                      -4.9
# 5  1942               14.6              35.1                     -20.5
# 6  1943                 24              78.6                     -54.6
# 7  1944               43.7              91.3                     -47.6
#
#   Constant $ Receipts Constant $ Outlays Constant $ Surplus/Deficit
# 3               100.3                145                      -44.7
# 4               120.3              188.6                      -68.2
# 5               177.8              426.9                     -249.1
# 6               263.2              861.3                     -598.2
# 7               522.7             1090.8                     -568.2

# %%
budget_df = budget_df.set_index('Year')

# %%
budget_df
# Out:
#      Current $ Receipts Current $ Outlays Current $ Surplus/Deficit  \
# Year
# 1940                6.5               9.5                      -2.9
# 1941                8.7              13.7                      -4.9
# 1942               14.6              35.1                     -20.5
# 1943                 24              78.6                     -54.6
# 1944               43.7              91.3                     -47.6
# ...                 ...               ...                       ...
# 2014             3021.5            3506.3                    -484.8
# 2015             3249.9            3691.8                      -442
# 2016               3268            3852.6                    -584.7
# 2017             3316.2            3981.6                    -665.4
# 2018             3329.9              4109                    -779.1
#
#      Constant $ Receipts Constant $ Outlays Constant $ Surplus/Deficit
# Year
# 1940               100.3                145                      -44.7
# 1941               120.3              188.6                      -68.2
# 1942               177.8              426.9                     -249.1
# 1943               263.2              861.3                     -598.2
# 1944               522.7             1090.8                     -568.2
# ...                  ...                ...                        ...
# 2014              2932.9             3403.5                     -470.6
# 2015              3137.6             3564.2                     -426.7
# 2016              3133.2             3693.8                     -560.5
# 2017              3126.4             3753.8                     -627.4
# 2018              3062.8             3779.5                     -716.6
#
# [80 rows x 6 columns]
