# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bud_xls_file = pd.ExcelFile('Fed_Budget_Deficit_Surplus_OMB.xlsx')

# %%
bud_xls_file.sheet_names
# Out:
# ['Table']

# %% [markdown]
# # Rename Desired Columns, drop

# %%
df = bud_xls_file.parse('Table')
df
# Out:
#    Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024  \
# 0                        (dollar amounts in billions)
# 1                                         Fiscal Year
# 2                                                 NaN
# 3                                                1940
# 4                                                1941
# ..                                                ...
# 84                                      2020 estimate
# 85                                      2021 estimate
# 86                                      2022 estimate
# 87                                      2023 estimate
# 88                                      2024 estimate
#
#             Unnamed: 1 Unnamed: 2              Unnamed: 3  \
# 0                  NaN        NaN                     NaN
# 1   In Current Dollars        NaN                     NaN
# 2             Receipts    Outlays  Surplus or Deficit (-)
# 3                  6.5        9.5                    -2.9
# 4                  8.7       13.7                    -4.9
# ..                 ...        ...                     ...
# 84              3644.8     4745.6                 -1100.8
# 85              3876.9     4945.2                 -1068.3
# 86              4128.6     5177.5                 -1048.8
# 87              4421.5     5330.1                  -908.6
# 88              4752.5       5453                  -700.5
#
#                        Unnamed: 4 Unnamed: 5              Unnamed: 6  \
# 0                             NaN        NaN                     NaN
# 1   In Constant (FY 2012) Dollars        NaN                     NaN
# 2                        Receipts    Outlays  Surplus or Deficit (-)
# 3                           100.3        145                   -44.7
# 4                           120.3      188.6                   -68.2
# ..                            ...        ...                     ...
# 84                         3209.3     4178.5                  -969.3
# 85                         3339.8     4260.2                  -920.3
# 86                         3479.1     4362.9                  -883.8
# 87                         3644.8     4393.8                    -749
# 88                           3833     4397.9                  -564.9
#
#                       Unnamed: 7             Unnamed: 8 Unnamed: 9  \
# 0                            NaN                    NaN        NaN
# 1   Addendum: Composite Deflator  As Percentages of GDP        NaN
# 2                            NaN               Receipts    Outlays
# 3                         0.0653                    6.7        9.6
# 4                         0.0724                    7.5       11.7
# ..                           ...                    ...        ...
# 84                        1.1357                   16.3       21.2
# 85                        1.1608                   16.5         21
# 86                        1.1867                   16.7       20.9
# 87                        1.2131                     17       20.5
# 88                        1.2399                   17.4         20
#
#                Unnamed: 10
# 0                      NaN
# 1                      NaN
# 2   Surplus or Deficit (-)
# 3                       -3
# 4                     -4.3
# ..                     ...
# 84                    -4.9
# 85                    -4.5
# 86                    -4.2
# 87                    -3.5
# 88                    -2.6
#
# [89 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
df = df.rename(columns={'Table 1.3 - SUMMARY OF RECEIPTS, OUTLAYS, AND SURPLUSES OR DEFICITS ( - ) IN CURRENT DOLLARS, CONSTANT (FY 2012) DOLLARS, AND AS PERCENTAGES OF GDP:  1940 - 2024':'Year',
                          'Unnamed: 1':'Current $ Receipts', 'Unnamed: 2':'Current $ Outlays', 'Unnamed: 3':'Current $ Surplus/Deficit', 'Unnamed: 4':'Constant $ Receipts', 'Unnamed: 5':'Constant $ Outlays',
                          'Unnamed: 6':'Constant $ Surplus/Deficit'})

# %%
df
# Out:
#                             Year  Current $ Receipts Current $ Outlays  \
# 0   (dollar amounts in billions)                 NaN               NaN
# 1                    Fiscal Year  In Current Dollars               NaN
# 2                            NaN            Receipts           Outlays
# 3                           1940                 6.5               9.5
# 4                           1941                 8.7              13.7
# ..                           ...                 ...               ...
# 84                 2020 estimate              3644.8            4745.6
# 85                 2021 estimate              3876.9            4945.2
# 86                 2022 estimate              4128.6            5177.5
# 87                 2023 estimate              4421.5            5330.1
# 88                 2024 estimate              4752.5              5453
#
#    Current $ Surplus/Deficit            Constant $ Receipts  \
# 0                        NaN                            NaN
# 1                        NaN  In Constant (FY 2012) Dollars
# 2     Surplus or Deficit (-)                       Receipts
# 3                       -2.9                          100.3
# 4                       -4.9                          120.3
# ..                       ...                            ...
# 84                   -1100.8                         3209.3
# 85                   -1068.3                         3339.8
# 86                   -1048.8                         3479.1
# 87                    -908.6                         3644.8
# 88                    -700.5                           3833
#
#    Constant $ Outlays Constant $ Surplus/Deficit  \
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2             Outlays     Surplus or Deficit (-)
# 3                 145                      -44.7
# 4               188.6                      -68.2
# ..                ...                        ...
# 84             4178.5                     -969.3
# 85             4260.2                     -920.3
# 86             4362.9                     -883.8
# 87             4393.8                       -749
# 88             4397.9                     -564.9
#
#                       Unnamed: 7             Unnamed: 8 Unnamed: 9  \
# 0                            NaN                    NaN        NaN
# 1   Addendum: Composite Deflator  As Percentages of GDP        NaN
# 2                            NaN               Receipts    Outlays
# 3                         0.0653                    6.7        9.6
# 4                         0.0724                    7.5       11.7
# ..                           ...                    ...        ...
# 84                        1.1357                   16.3       21.2
# 85                        1.1608                   16.5         21
# 86                        1.1867                   16.7       20.9
# 87                        1.2131                     17       20.5
# 88                        1.2399                   17.4         20
#
#                Unnamed: 10
# 0                      NaN
# 1                      NaN
# 2   Surplus or Deficit (-)
# 3                       -3
# 4                     -4.3
# ..                     ...
# 84                    -4.9
# 85                    -4.5
# 86                    -4.2
# 87                    -3.5
# 88                    -2.6
#
# [89 rows x 11 columns]

# %%
budget_df = df[['Year','Current $ Receipts','Current $ Outlays','Current $ Surplus/Deficit','Constant $ Receipts','Constant $ Outlays','Constant $ Surplus/Deficit']].copy()

# %%
budget_df
# Out:
#                             Year  Current $ Receipts Current $ Outlays  \
# 0   (dollar amounts in billions)                 NaN               NaN
# 1                    Fiscal Year  In Current Dollars               NaN
# 2                            NaN            Receipts           Outlays
# 3                           1940                 6.5               9.5
# 4                           1941                 8.7              13.7
# ..                           ...                 ...               ...
# 84                 2020 estimate              3644.8            4745.6
# 85                 2021 estimate              3876.9            4945.2
# 86                 2022 estimate              4128.6            5177.5
# 87                 2023 estimate              4421.5            5330.1
# 88                 2024 estimate              4752.5              5453
#
#    Current $ Surplus/Deficit            Constant $ Receipts  \
# 0                        NaN                            NaN
# 1                        NaN  In Constant (FY 2012) Dollars
# 2     Surplus or Deficit (-)                       Receipts
# 3                       -2.9                          100.3
# 4                       -4.9                          120.3
# ..                       ...                            ...
# 84                   -1100.8                         3209.3
# 85                   -1068.3                         3339.8
# 86                   -1048.8                         3479.1
# 87                    -908.6                         3644.8
# 88                    -700.5                           3833
#
#    Constant $ Outlays Constant $ Surplus/Deficit
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2             Outlays     Surplus or Deficit (-)
# 3                 145                      -44.7
# 4               188.6                      -68.2
# ..                ...                        ...
# 84             4178.5                     -969.3
# 85             4260.2                     -920.3
# 86             4362.9                     -883.8
# 87             4393.8                       -749
# 88             4397.9                     -564.9
#
# [89 rows x 7 columns]

# %%
budget_df = budget_df.drop(0)
budget_df = budget_df.drop(1)
budget_df = budget_df.drop(2)

# %%
budget_df.tail(30)
# Out:
#              Year Current $ Receipts Current $ Outlays  \
# 59           1995             1351.8            1515.7
# 60           1996             1453.1            1560.5
# 61           1997             1579.2            1601.1
# 62           1998             1721.7            1652.5
# 63           1999             1827.5            1701.8
# 64           2000             2025.2              1789
# 65           2001             1991.1            1862.8
# 66           2002             1853.1            2010.9
# 67           2003             1782.3            2159.9
# 68           2004             1880.1            2292.8
# 69           2005             2153.6              2472
# 70           2006             2406.9              2655
# 71           2007               2568            2728.7
# 72           2008               2524            2982.5
# 73           2009               2105            3517.7
# 74           2010             2162.7            3457.1
# 75           2011             2303.5            3603.1
# 76           2012               2450            3526.6
# 77           2013             2775.1            3454.9
# 78           2014             3021.5            3506.3
# 79           2015             3249.9            3691.8
# 80           2016               3268            3852.6
# 81           2017             3316.2            3981.6
# 82           2018             3329.9              4109
# 83  2019 estimate             3437.7            4529.2
# 84  2020 estimate             3644.8            4745.6
# 85  2021 estimate             3876.9            4945.2
# 86  2022 estimate             4128.6            5177.5
# 87  2023 estimate             4421.5            5330.1
# 88  2024 estimate             4752.5              5453
#
#    Current $ Surplus/Deficit Constant $ Receipts Constant $ Outlays  \
# 59                      -164                1960             2197.7
# 60                    -107.4              2063.4               2216
# 61                     -21.9              2196.4             2226.9
# 62                      69.3              2374.8             2279.3
# 63                     125.6              2490.1             2318.9
# 64                     236.2              2691.3             2377.3
# 65                     128.2              2578.5             2412.4
# 66                    -157.8              2363.4             2564.6
# 67                    -377.6              2210.2             2678.4
# 68                    -412.7              2272.3             2771.1
# 69                    -318.3              2516.5             2888.5
# 70                    -248.2              2718.4             2998.7
# 71                    -160.7              2822.3             2998.9
# 72                    -458.6              2681.1             3168.2
# 73                   -1412.7              2236.3               3737
# 74                   -1294.4              2257.3             3608.3
# 75                   -1299.6              2349.3             3674.7
# 76                   -1076.6                2450             3526.6
# 77                    -679.8              2736.3             3406.5
# 78                    -484.8              2932.9             3403.5
# 79                      -442              3137.6             3564.2
# 80                    -584.7              3133.2             3693.8
# 81                    -665.4              3126.4             3753.8
# 82                    -779.1              3062.8             3779.5
# 83                   -1091.5              3093.9             4076.3
# 84                   -1100.8              3209.3             4178.5
# 85                   -1068.3              3339.8             4260.2
# 86                   -1048.8              3479.1             4362.9
# 87                    -908.6              3644.8             4393.8
# 88                    -700.5                3833             4397.9
#
#    Constant $ Surplus/Deficit
# 59                     -237.7
# 60                     -152.6
# 61                      -30.4
# 62                       95.5
# 63                      171.2
# 64                      313.9
# 65                      166.1
# 66                     -201.2
# 67                     -468.2
# 68                     -498.8
# 69                       -372
# 70                     -280.3
# 71                     -176.6
# 72                     -487.1
# 73                    -1500.8
# 74                      -1351
# 75                    -1325.4
# 76                    -1076.6
# 77                     -670.3
# 78                     -470.6
# 79                     -426.7
# 80                     -560.5
# 81                     -627.4
# 82                     -716.6
# 83                     -982.4
# 84                     -969.3
# 85                     -920.3
# 86                     -883.8
# 87                       -749
# 88                     -564.9
